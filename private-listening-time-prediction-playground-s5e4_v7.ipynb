# %%
# We load the competition data

import warnings
warnings.filterwarnings("ignore")

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/playground-series-s5e4/sample_submission.csv
# /kaggle/input/playground-series-s5e4/train.csv
# /kaggle/input/playground-series-s5e4/test.csv

# %% [markdown]
# # Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import shap

from sklearn.preprocessing import (
    OrdinalEncoder,
    StandardScaler,
    MinMaxScaler
)
from sklearn.feature_selection import (
    mutual_info_regression
)
from sklearn.model_selection import (
    train_test_split,
    cross_val_score,
    KFold,
    RandomizedSearchCV
)
from sklearn.metrics import (
    r2_score, 
    mean_squared_error
)
from sklearn.impute import KNNImputer
from xgboost import XGBRegressor
from sklearn.ensemble import BaggingRegressor
from catboost import CatBoostRegressor

# %% [markdown]
# # Primer análisis

# %% [markdown]
# Notebook y análisis completo:
#
# https://www.kaggle.com/code/les1781/listening-time-prediction-playground-series-s5-e4

# %%
# We load the data

listening_new = pd.read_csv("/kaggle/input/playground-series-s5e4/train.csv", index_col="id")

# %% [markdown]
# # Data wrangling

# %%
# We check for null values

null_values = (
    pd.DataFrame(
        {f"Amount of Null Data": listening_new.isnull().sum(), 
         "Percentage of Null Data" : (
             listening_new.isnull().sum()) / (len(listening_new)) * (100)
        }))

null_values.style.background_gradient(cmap="Greens")
# Out:
# <style type="text/css">
# #T_a4fe0_row0_col0, #T_a4fe0_row0_col1, #T_a4fe0_row1_col0, #T_a4fe0_row1_col1, #T_a4fe0_row3_col0, #T_a4fe0_row3_col1, #T_a4fe0_row4_col0, #T_a4fe0_row4_col1, #T_a4fe0_row5_col0, #T_a4fe0_row5_col1, #T_a4fe0_row6_col0, #T_a4fe0_row6_col1, #T_a4fe0_row8_col0, #T_a4fe0_row8_col1, #T_a4fe0_row9_col0, #T_a4fe0_row9_col1, #T_a4fe0_row10_col0, #T_a4fe0_row10_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_a4fe0_row2_col0, #T_a4fe0_row2_col1 {
#   background-color: #4db163;
#   color: #f1f1f1;
# }
# #T_a4fe0_row7_col0, #T_a4fe0_row7_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a4fe0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a4fe0_level0_col0" class="col_heading level0 col0" >Amount of Null Data</th>
#       <th id="T_a4fe0_level0_col1" class="col_heading level0 col1" >Percentage of Null Data</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a4fe0_level0_row0" class="row_heading level0 row0" >Podcast_Name</th>
#       <td id="T_a4fe0_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_a4fe0_row0_col1" class="data row0 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a4fe0_level0_row1" class="row_heading level0 row1" >Episode_Title</th>
#       <td id="T_a4fe0_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_a4fe0_row1_col1" class="data row1 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a4fe0_level0_row2" class="row_heading level0 row2" >Episode_Length_minutes</th>
#       <td id="T_a4fe0_row2_col0" class="data row2 col0" >87093</td>
#       <td id="T_a4fe0_row2_col1" class="data row2 col1" >11.612400</td>
#     </tr>
#     <tr>
#       <th id="T_a4fe0_level0_row3" class="row_heading level0 row3" >Genre</th>
#       <td id="T_a4fe0_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_a4fe0_row3_col1" class="data row3 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a4fe0_level0_row4" class="row_heading level0 row4" >Host_Popularity_percentage</th>
#       <td id="T_a4fe0_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_a4fe0_row4_col1" class="data row4 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a4fe0_level0_row5" class="row_heading level0 row5" >Publication_Day</th>
#       <td id="T_a4fe0_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_a4fe0_row5_col1" class="data row5 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a4fe0_level0_row6" class="row_heading level0 row6" >Publication_Time</th>
#       <td id="T_a4fe0_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_a4fe0_row6_col1" class="data row6 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a4fe0_level0_row7" class="row_heading level0 row7" >Guest_Popularity_percentage</th>
#       <td id="T_a4fe0_row7_col0" class="data row7 col0" >146030</td>
#       <td id="T_a4fe0_row7_col1" class="data row7 col1" >19.470667</td>
#     </tr>
#     <tr>
#       <th id="T_a4fe0_level0_row8" class="row_heading level0 row8" >Number_of_Ads</th>
#       <td id="T_a4fe0_row8_col0" class="data row8 col0" >1</td>
#       <td id="T_a4fe0_row8_col1" class="data row8 col1" >0.000133</td>
#     </tr>
#     <tr>
#       <th id="T_a4fe0_level0_row9" class="row_heading level0 row9" >Episode_Sentiment</th>
#       <td id="T_a4fe0_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_a4fe0_row9_col1" class="data row9 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a4fe0_level0_row10" class="row_heading level0 row10" >Listening_Time_minutes</th>
#       <td id="T_a4fe0_row10_col0" class="data row10 col0" >0</td>
#       <td id="T_a4fe0_row10_col1" class="data row10 col1" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# We replace the erroneous values


listening_new["Number_of_Ads"] = listening_new["Number_of_Ads"].apply(lambda x: np.NaN if x>3 else x)

listening_new["Episode_Length_minutes"] = (
    listening_new["Episode_Length_minutes"].apply(lambda x: np.NaN if x>125.0 else x)
)

listening_new["Host_Popularity_percentage"] = np.where(
    listening_new["Host_Popularity_percentage"] > 100, 100, listening_new["Host_Popularity_percentage"]
).round(decimals=2)

listening_new["Guest_Popularity_percentage"] = np.where(
    listening_new["Guest_Popularity_percentage"] > 100, 100, listening_new["Guest_Popularity_percentage"]
).round(decimals=2)

# %%
# We fill null values with the mean and mode groupby Podcast

listening_new["Number_of_Ads"] = listening_new["Number_of_Ads"].fillna(
        listening_new.groupby("Podcast_Name")["Number_of_Ads"].transform(lambda v: v.mode()[0])
)

listening_new["Episode_Length_minutes"] = (listening_new["Episode_Length_minutes"].fillna(
    listening_new.groupby("Podcast_Name")["Episode_Length_minutes"].transform("median")
))

listening_new["Guest_Popularity_percentage"] = (listening_new["Guest_Popularity_percentage"].fillna(
        listening_new.groupby("Podcast_Name")["Guest_Popularity_percentage"].transform("median")
))

# %%
# 1) polynomial / transforms of Episode_Length_minutes

listening_new["len_log"] = np.log1p(listening_new["Episode_Length_minutes"])
listening_new["len_sq"]  = listening_new["Episode_Length_minutes"] ** 2
listening_new["len_cubert"] = np.cbrt(listening_new["Episode_Length_minutes"])

# %%
# 2) host/guest Popularity_percentage transforms

listening_new["host_log"] = np.log1p(listening_new["Host_Popularity_percentage"])
listening_new["host_sq"] = listening_new["Host_Popularity_percentage"] ** 2
listening_new["guest_log"] = np.log1p(listening_new["Guest_Popularity_percentage"])
listening_new["guest_sq"] = listening_new["Guest_Popularity_percentage"] ** 2
listening_new["pop_diff"] = listening_new["Host_Popularity_percentage"] - listening_new["Guest_Popularity_percentage"]
listening_new["pop_sum"] = listening_new["Host_Popularity_percentage"] + listening_new["Guest_Popularity_percentage"]
listening_new["pop_ratio"] = listening_new["Host_Popularity_percentage"] / (listening_new["Guest_Popularity_percentage"] + 1)

# %%
# 3) Number_of_Ads transforms

listening_new["ads_log"] = np.log1p(listening_new["Number_of_Ads"])
listening_new["ads_per_min"] = listening_new["Number_of_Ads"] / (listening_new["Episode_Length_minutes"] + 1)

# %%
# We changed the format for more efficient memory usage

listening_new[listening_new.select_dtypes(["object"]).columns] = (
    listening_new.select_dtypes(["object"]).apply(
        lambda x: x.astype("category"))
)

# %%
listening_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 750000 entries, 0 to 749999
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Podcast_Name                 750000 non-null  category
#  1   Episode_Title                750000 non-null  category
#  2   Episode_Length_minutes       750000 non-null  float64
#  3   Genre                        750000 non-null  category
#  4   Host_Popularity_percentage   750000 non-null  float64
#  5   Publication_Day              750000 non-null  category
#  6   Publication_Time             750000 non-null  category
#  7   Guest_Popularity_percentage  750000 non-null  float64
#  8   Number_of_Ads                750000 non-null  float64
#  9   Episode_Sentiment            750000 non-null  category
#  10  Listening_Time_minutes       750000 non-null  float64
#  11  len_log                      750000 non-null  float64
#  12  len_sq                       750000 non-null  float64
#  13  len_cubert                   750000 non-null  float64
#  14  host_log                     750000 non-null  float64
#  15  host_sq                      750000 non-null  float64
#  16  guest_log                    750000 non-null  float64
#  17  guest_sq                     750000 non-null  float64
#  18  pop_diff                     750000 non-null  float64
#  19  pop_sum                      750000 non-null  float64
#  20  pop_ratio                    750000 non-null  float64
#  21  ads_log                      750000 non-null  float64
#  22  ads_per_min                  750000 non-null  float64
# dtypes: category(6), float64(17)
# memory usage: 107.3 MB

# %% [markdown]
# # Data preprocessing

# %%
listening_end = listening_new.copy()

# %%
# We map the variables and change the format

eps_order = {"Negative" : 0, "Neutral" : 1, "Positive" : 2}
listening_end["Episode_Sentiment"] = listening_end["Episode_Sentiment"].map(eps_order)
listening_end["Episode_Sentiment"] = listening_end["Episode_Sentiment"].astype("float64")

# %%
listening_end["Episode_Title"] = listening_end["Episode_Title"].str.strip("Episode ").astype("float64")

# %%
# We separate the categorical variables from the numerical ones

df_numerical = listening_end.select_dtypes(include="number")
df_categorical = listening_end.select_dtypes(include="category")

# %%
df_categorical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 750000 entries, 0 to 749999
# Data columns (total 4 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Podcast_Name      750000 non-null  category
#  1   Genre             750000 non-null  category
#  2   Publication_Day   750000 non-null  category
#  3   Publication_Time  750000 non-null  category
# dtypes: category(4)
# memory usage: 8.6 MB

# %% [markdown]
# ## Encode

# %%
# We apply OrdinalEncoder to the remaining categorical variables

enc = OrdinalEncoder(categories="auto").set_output(transform="pandas")

enc_data = enc.fit_transform(df_categorical)

df_listening = pd.concat([enc_data, df_numerical], axis=1)

# %%
df_listening.corr().style.background_gradient(cmap="Greens")
# Out:
# <style type="text/css">
# #T_300b3_row0_col0, #T_300b3_row1_col1, #T_300b3_row2_col2, #T_300b3_row3_col3, #T_300b3_row4_col4, #T_300b3_row5_col5, #T_300b3_row6_col6, #T_300b3_row7_col7, #T_300b3_row8_col8, #T_300b3_row9_col9, #T_300b3_row10_col10, #T_300b3_row11_col11, #T_300b3_row12_col12, #T_300b3_row13_col13, #T_300b3_row14_col14, #T_300b3_row15_col15, #T_300b3_row16_col16, #T_300b3_row17_col17, #T_300b3_row18_col18, #T_300b3_row19_col19, #T_300b3_row20_col20, #T_300b3_row21_col21, #T_300b3_row22_col22 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_300b3_row0_col1, #T_300b3_row1_col19, #T_300b3_row2_col19 {
#   background-color: #d4eece;
#   color: #000000;
# }
# #T_300b3_row0_col2, #T_300b3_row0_col3, #T_300b3_row1_col2, #T_300b3_row1_col3, #T_300b3_row1_col6, #T_300b3_row1_col14, #T_300b3_row2_col0, #T_300b3_row2_col3, #T_300b3_row2_col14, #T_300b3_row3_col1, #T_300b3_row4_col0, #T_300b3_row4_col2, #T_300b3_row4_col3, #T_300b3_row5_col0, #T_300b3_row5_col1, #T_300b3_row5_col2, #T_300b3_row7_col2, #T_300b3_row7_col3, #T_300b3_row8_col1, #T_300b3_row8_col2, #T_300b3_row8_col3, #T_300b3_row8_col9, #T_300b3_row9_col0, #T_300b3_row9_col1, #T_300b3_row9_col2, #T_300b3_row10_col0, #T_300b3_row10_col2, #T_300b3_row10_col4, #T_300b3_row11_col0, #T_300b3_row11_col1, #T_300b3_row11_col2, #T_300b3_row12_col1, #T_300b3_row12_col4, #T_300b3_row13_col0, #T_300b3_row13_col1, #T_300b3_row13_col2, #T_300b3_row16_col2, #T_300b3_row16_col3, #T_300b3_row17_col3, #T_300b3_row18_col0, #T_300b3_row18_col4, #T_300b3_row19_col1, #T_300b3_row19_col3, #T_300b3_row20_col0, #T_300b3_row20_col1, #T_300b3_row21_col1, #T_300b3_row21_col2, #T_300b3_row21_col3, #T_300b3_row21_col9, #T_300b3_row21_col15, #T_300b3_row22_col0, #T_300b3_row22_col1, #T_300b3_row22_col2, #T_300b3_row22_col6, #T_300b3_row22_col14, #T_300b3_row22_col15 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_300b3_row0_col4, #T_300b3_row0_col9, #T_300b3_row1_col4, #T_300b3_row2_col9, #T_300b3_row5_col14, #T_300b3_row8_col4, #T_300b3_row9_col15, #T_300b3_row13_col14, #T_300b3_row16_col9, #T_300b3_row16_col14, #T_300b3_row18_col9, #T_300b3_row21_col4 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_300b3_row0_col5, #T_300b3_row2_col5, #T_300b3_row8_col13, #T_300b3_row21_col13 {
#   background-color: #acdea6;
#   color: #000000;
# }
# #T_300b3_row0_col6, #T_300b3_row0_col14, #T_300b3_row1_col15, #T_300b3_row2_col1, #T_300b3_row2_col6, #T_300b3_row3_col14, #T_300b3_row6_col3, #T_300b3_row8_col0, #T_300b3_row12_col0, #T_300b3_row12_col2, #T_300b3_row14_col3, #T_300b3_row15_col3, #T_300b3_row16_col1, #T_300b3_row20_col3, #T_300b3_row20_col4, #T_300b3_row21_col0 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_300b3_row0_col7, #T_300b3_row0_col16, #T_300b3_row1_col17, #T_300b3_row1_col18, #T_300b3_row3_col16, #T_300b3_row5_col7, #T_300b3_row5_col16, #T_300b3_row11_col16, #T_300b3_row12_col7, #T_300b3_row12_col16, #T_300b3_row13_col16, #T_300b3_row22_col18, #T_300b3_row22_col20 {
#   background-color: #91d28e;
#   color: #000000;
# }
# #T_300b3_row0_col8, #T_300b3_row7_col8, #T_300b3_row16_col21 {
#   background-color: #e6f5e1;
#   color: #000000;
# }
# #T_300b3_row0_col10, #T_300b3_row1_col10, #T_300b3_row2_col10, #T_300b3_row20_col10 {
#   background-color: #b2e0ac;
#   color: #000000;
# }
# #T_300b3_row0_col11, #T_300b3_row2_col22, #T_300b3_row9_col13, #T_300b3_row16_col22, #T_300b3_row19_col11 {
#   background-color: #9ed798;
#   color: #000000;
# }
# #T_300b3_row0_col12, #T_300b3_row2_col12, #T_300b3_row19_col12 {
#   background-color: #bae3b3;
#   color: #000000;
# }
# #T_300b3_row0_col13, #T_300b3_row3_col22, #T_300b3_row15_col22, #T_300b3_row19_col13 {
#   background-color: #a2d99c;
#   color: #000000;
# }
# #T_300b3_row0_col15, #T_300b3_row2_col15, #T_300b3_row3_col6, #T_300b3_row4_col1, #T_300b3_row7_col1, #T_300b3_row9_col4, #T_300b3_row10_col1, #T_300b3_row17_col18, #T_300b3_row18_col3 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_300b3_row0_col17, #T_300b3_row3_col17, #T_300b3_row5_col17, #T_300b3_row8_col20, #T_300b3_row21_col20, #T_300b3_row22_col17 {
#   background-color: #94d390;
#   color: #000000;
# }
# #T_300b3_row0_col18, #T_300b3_row1_col7, #T_300b3_row1_col16, #T_300b3_row3_col18, #T_300b3_row6_col17, #T_300b3_row9_col18, #T_300b3_row10_col20, #T_300b3_row14_col17, #T_300b3_row15_col17, #T_300b3_row21_col7, #T_300b3_row22_col16 {
#   background-color: #8ed08b;
#   color: #000000;
# }
# #T_300b3_row0_col19, #T_300b3_row1_col0, #T_300b3_row3_col19, #T_300b3_row8_col19, #T_300b3_row20_col6, #T_300b3_row20_col15, #T_300b3_row21_col19, #T_300b3_row22_col19 {
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_300b3_row0_col20, #T_300b3_row1_col20, #T_300b3_row2_col7, #T_300b3_row2_col16, #T_300b3_row2_col18, #T_300b3_row2_col20, #T_300b3_row3_col7, #T_300b3_row3_col20, #T_300b3_row5_col20, #T_300b3_row9_col7, #T_300b3_row9_col16, #T_300b3_row9_col20, #T_300b3_row11_col7, #T_300b3_row11_col20, #T_300b3_row12_col20, #T_300b3_row13_col7, #T_300b3_row13_col20, #T_300b3_row22_col7 {
#   background-color: #90d18d;
#   color: #000000;
# }
# #T_300b3_row0_col21, #T_300b3_row2_col8, #T_300b3_row4_col8, #T_300b3_row7_col21 {
#   background-color: #e7f6e2;
#   color: #000000;
# }
# #T_300b3_row0_col22, #T_300b3_row1_col11, #T_300b3_row1_col22, #T_300b3_row2_col11, #T_300b3_row6_col13, #T_300b3_row7_col22, #T_300b3_row15_col13, #T_300b3_row17_col11, #T_300b3_row20_col11 {
#   background-color: #9fd899;
#   color: #000000;
# }
# #T_300b3_row1_col5, #T_300b3_row20_col5 {
#   background-color: #aedea7;
#   color: #000000;
# }
# #T_300b3_row1_col8, #T_300b3_row17_col21, #T_300b3_row18_col19, #T_300b3_row19_col8 {
#   background-color: #e8f6e3;
#   color: #000000;
# }
# #T_300b3_row1_col9, #T_300b3_row2_col4, #T_300b3_row4_col9, #T_300b3_row7_col9, #T_300b3_row9_col6, #T_300b3_row10_col3, #T_300b3_row11_col3, #T_300b3_row11_col14, #T_300b3_row17_col9, #T_300b3_row20_col9 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_300b3_row1_col12, #T_300b3_row20_col12 {
#   background-color: #bbe4b4;
#   color: #000000;
# }
# #T_300b3_row1_col13, #T_300b3_row2_col13, #T_300b3_row17_col13, #T_300b3_row20_col13 {
#   background-color: #a3da9d;
#   color: #000000;
# }
# #T_300b3_row1_col21, #T_300b3_row3_col8, #T_300b3_row19_col21 {
#   background-color: #e8f6e4;
#   color: #000000;
# }
# #T_300b3_row2_col17, #T_300b3_row4_col18, #T_300b3_row4_col20, #T_300b3_row8_col17, #T_300b3_row8_col18, #T_300b3_row9_col17, #T_300b3_row10_col7, #T_300b3_row10_col16, #T_300b3_row11_col17, #T_300b3_row13_col17, #T_300b3_row21_col17, #T_300b3_row21_col18 {
#   background-color: #92d28f;
#   color: #000000;
# }
# #T_300b3_row2_col21, #T_300b3_row4_col21, #T_300b3_row17_col8 {
#   background-color: #e7f6e3;
#   color: #000000;
# }
# #T_300b3_row3_col0, #T_300b3_row3_col2, #T_300b3_row5_col4, #T_300b3_row6_col0, #T_300b3_row6_col1, #T_300b3_row6_col2, #T_300b3_row7_col0, #T_300b3_row7_col18, #T_300b3_row8_col6, #T_300b3_row8_col14, #T_300b3_row8_col15, #T_300b3_row10_col8, #T_300b3_row10_col21, #T_300b3_row11_col4, #T_300b3_row11_col22, #T_300b3_row13_col4, #T_300b3_row14_col0, #T_300b3_row14_col1, #T_300b3_row14_col2, #T_300b3_row15_col0, #T_300b3_row15_col1, #T_300b3_row15_col2, #T_300b3_row16_col0, #T_300b3_row16_col20, #T_300b3_row17_col0, #T_300b3_row17_col2, #T_300b3_row18_col1, #T_300b3_row18_col2, #T_300b3_row18_col7, #T_300b3_row18_col17, #T_300b3_row19_col0, #T_300b3_row19_col2, #T_300b3_row20_col2, #T_300b3_row20_col16, #T_300b3_row20_col19, #T_300b3_row21_col6, #T_300b3_row21_col14, #T_300b3_row22_col3, #T_300b3_row22_col5, #T_300b3_row22_col9, #T_300b3_row22_col10, #T_300b3_row22_col11, #T_300b3_row22_col12, #T_300b3_row22_col13 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_300b3_row3_col4, #T_300b3_row3_col15, #T_300b3_row5_col3, #T_300b3_row9_col3, #T_300b3_row9_col14, #T_300b3_row12_col3, #T_300b3_row13_col3, #T_300b3_row13_col22, #T_300b3_row17_col1 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_300b3_row3_col5, #T_300b3_row9_col10, #T_300b3_row14_col10, #T_300b3_row19_col5 {
#   background-color: #abdda5;
#   color: #000000;
# }
# #T_300b3_row3_col

# %%
df_listening.describe().T
# Out:
#                                 count         mean          std        min  \
# Podcast_Name                 750000.0    23.515731    14.137577   0.000000
# Genre                        750000.0     4.648788     2.963073   0.000000
# Publication_Day              750000.0     2.962776     1.997399   0.000000
# Publication_Time             750000.0     1.522868     1.119361   0.000000
# Episode_Title                750000.0    51.445811    28.085623   1.000000
# Episode_Length_minutes       750000.0    64.433284    31.004973   0.000000
# Host_Popularity_percentage   750000.0    59.859482    22.872221   1.300000
# Guest_Popularity_percentage  750000.0    52.486190    25.540435   0.000000
# Number_of_Ads                750000.0     1.347873     1.110966   0.000000
# Episode_Sentiment            750000.0     0.997969     0.815440   0.000000
# Listening_Time_minutes       750000.0    45.437406    27.138306   0.000000
# len_log                      750000.0     4.022679     0.632706   0.000000
# len_sq                       750000.0  5112.955169  4115.919558   0.000000
# len_cubert                   750000.0     3.876010     0.747862   0.000000
# host_log                     750000.0     4.026795     0.421991   0.832909
# host_sq                      750000.0  4106.295423  2780.020770   1.690000
# guest_log                    750000.0     3.781547     0.767213   0.000000
# guest_sq                     750000.0  3407.113160  2687.199049   0.000000
# pop_diff                     750000.0     7.373292    33.936481 -79.510000
# pop_sum                      750000.0   112.345673    34.629755   7.510000
# pop_ratio                    750000.0     2.201625     4.607138   0.026592
# ads_log                      750000.0     0.725578     0.524993   0.000000
# ads_per_min                  750000.0     0.031747     0.046611   0.000000
#
#                                      25%          50%          75%  \
# Podcast_Name                   11.000000    23.000000    37.000000
# Genre                           2.000000     5.000000     7.000000
# Publication_Day                 1.000000     3.000000     5.000000
# Publication_Time                1.000000     1.000000     3.000000
# Episode_Title                  28.000000    52.000000    75.000000
# Episode_Length_minutes         39.420000    63.840000    90.310000
# Host_Popularity_percentage     39.410000    60.050000    79.530000
# Guest_Popularity_percentage    34.550000    53.720000    71.040000
# Number_of_Ads                   0.000000     1.000000     2.000000
# Episode_Sentiment               0.000000     1.000000     2.000000
# Listening_Time_minutes         23.178350    43.379460    64.811580
# len_log                         3.699325     4.171923     4.514260
# len_sq                       1553.936400  4075.545600  8155.896100
# len_cubert                      3.403342     3.996664     4.486544
# host_log                        3.699077     4.111693     4.388630
# host_sq                      1553.148100  3606.002500  6325.020900
# guest_log                       3.570940     4.002229     4.277222
# guest_sq                     1193.702500  2885.838400  5046.681600
# pop_diff                      -17.140000     6.735000    30.920000
# pop_sum                        87.495000   112.860000   137.280000
# pop_ratio                       0.720614     1.103883     1.745050
# ads_log                         0.000000     0.693147     1.098612
# ads_per_min                     0.000000     0.018671     0.039769
#
#                                       max
# Podcast_Name                    47.000000
# Genre                            9.000000
# Publication_Day                  6.000000
# Publication_Time                 3.000000
# Episode_Title                  100.000000
# Episode_Length_minutes         120.930000
# Host_Popularity_percentage     100.000000
# Guest_Popularity_percentage    100.000000
# Number_of_Ads                    3.000000
# Episode_Sentiment                2.000000
# Listening_Time_minutes         119.970000
# len_log                          4.803447
# len_sq                       14624.064900
# len_cubert                       4.945133
# host_log                         4.615121
# host_sq                      10000.000000
# guest_log                        4.615121
# guest_sq                     10000.000000
# pop_diff                        99.950000
# pop_sum                        199.920000
# pop_ratio                       98.792079
# ads_log                          1.386294
# ads_per_min                      0.503778

# %% [markdown]
# ## Scaling

# %%
# We separate the target variable from the features and data to scale

x_listening = df_listening.drop(columns="Listening_Time_minutes")
y_listening = df_listening["Listening_Time_minutes"]

# %%
# Numerical variables to scale

df_numeric = x_listening[[
    "Podcast_Name",
    "Episode_Title",
    "Episode_Length_minutes",
    "Host_Popularity_percentage",
    "Guest_Popularity_percentage"
]]

scaler = StandardScaler().set_output(transform="pandas")
scale_num = scaler.fit_transform(df_numeric)

# We create a df with the remaining variables

df_rest = x_listening[[
    "Genre",
    "Publication_Day",
    "Publication_Time",
    "Number_of_Ads",
    "Episode_Sentiment"
]]

df_new_fe = x_listening.drop(columns=
                             ["Podcast_Name",
                             "Episode_Title",
                             "Episode_Length_minutes",
                             "Host_Popularity_percentage",
                             "Guest_Popularity_percentage",
                             "Genre",
                             "Publication_Day",
                             "Publication_Time",
                             "Number_of_Ads",
                             "Episode_Sentiment"]
                            )

mm_scaler = MinMaxScaler().set_output(transform="pandas")
scale_mm = mm_scaler.fit_transform(df_new_fe)

# We concatenate the dataframes

x_end = pd.concat([df_rest, scale_num, scale_mm], axis=1)

# %%
x_end.describe().T
# Out:
#                                 count          mean       std       min  \
# Genre                        750000.0  4.648788e+00  2.963073  0.000000
# Publication_Day              750000.0  2.962776e+00  1.997399  0.000000
# Publication_Time             750000.0  1.522868e+00  1.119361  0.000000
# Number_of_Ads                750000.0  1.347873e+00  1.110966  0.000000
# Episode_Sentiment            750000.0  9.979693e-01  0.815440  0.000000
# Podcast_Name                 750000.0  1.788673e-17  1.000001 -1.663351
# Episode_Title                750000.0  4.092726e-18  1.000001 -1.796145
# Episode_Length_minutes       750000.0  5.373598e-17  1.000001 -2.078161
# Host_Popularity_percentage   750000.0 -2.175208e-16  1.000001 -2.560290
# Guest_Popularity_percentage  750000.0  1.577594e-16  1.000001 -2.055025
# len_log                      750000.0  8.374567e-01  0.131719  0.000000
# len_sq                       750000.0  3.496261e-01  0.281448  0.000000
# len_cubert                   750000.0  7.838029e-01  0.151232  0.000000
# host_log                     750000.0  8.444494e-01  0.111573  0.000000
# host_sq                      750000.0  4.105299e-01  0.278049  0.000000
# guest_log                    750000.0  8.193821e-01  0.166239  0.000000
# guest_sq                     750000.0  3.407113e-01  0.268720  0.000000
# pop_diff                     750000.0  4.841374e-01  0.189103  0.000000
# pop_sum                      750000.0  5.448556e-01  0.179979  0.000000
# pop_ratio                    750000.0  2.202219e-02  0.046647  0.000000
# ads_log                      750000.0  5.233942e-01  0.378702  0.000000
# ads_per_min                  750000.0  6.301730e-02  0.092523  0.000000
#
#                                   25%       50%       75%       max
# Genre                        2.000000  5.000000  7.000000  9.000000
# Publication_Day              1.000000  3.000000  5.000000  6.000000
# Publication_Time             1.000000  1.000000  3.000000  3.000000
# Number_of_Ads                0.000000  1.000000  2.000000  3.000000
# Episode_Sentiment            0.000000  1.000000  2.000000  2.000000
# Podcast_Name                -0.885282 -0.036479  0.953790  1.661125
# Episode_Title               -0.834798  0.019732  0.838657  1.728793
# Episode_Length_minutes      -0.806751 -0.019135  0.834599  1.822184
# Host_Popularity_percentage  -0.894076  0.008330  0.860018  1.754991
# Guest_Popularity_percentage -0.702267  0.048308  0.726449  1.860338
# len_log                      0.770140  0.868527  0.939796  1.000000
# len_sq                       0.106259  0.278688  0.557704  1.000000
# len_cubert                   0.688220  0.808201  0.907265  1.000000
# host_log                     0.757802  0.866896  0.940117  1.000000
# host_sq                      0.155172  0.360492  0.632440  1.000000
# guest_log                    0.773748  0.867199  0.926784  1.000000
# guest_sq                     0.119370  0.288584  0.504668  1.000000
# pop_diff                     0.347543  0.480581  0.615346  1.000000
# pop_sum                      0.415701  0.547529  0.674445  1.000000
# pop_ratio                    0.007027  0.010908  0.017399  1.000000
# ads_log                      0.000000  0.500000  0.792481  1.000000
# ads_per_min                  0.000000  0.037061  0.078942  1.000000

# %% [markdown]
# ## Feature Selection

# %%
'''
mi_scores = mutual_info_regression(x_end, y_listening)
mi_scores = pd.Series(mi_scores, name="MI Scores", index=x_end.columns)
mi_scores = mi_scores.sort_values(ascending=False)
mi_scores
'''
# Out:
# '\nmi_scores = mutual_info_regression(x_end, y_listening)\nmi_scores = pd.Series(mi_scores, name="MI Scores", index=x_end.columns)\nmi_scores = mi_scores.sort_values(ascending=False)\nmi_scores\n'

# %%
x_end.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 750000 entries, 0 to 749999
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Genre                        750000 non-null  float64
#  1   Publication_Day              750000 non-null  float64
#  2   Publication_Time             750000 non-null  float64
#  3   Number_of_Ads                750000 non-null  float64
#  4   Episode_Sentiment            750000 non-null  float64
#  5   Podcast_Name                 750000 non-null  float64
#  6   Episode_Title                750000 non-null  float64
#  7   Episode_Length_minutes       750000 non-null  float64
#  8   Host_Popularity_percentage   750000 non-null  float64
#  9   Guest_Popularity_percentage  750000 non-null  float64
#  10  len_log                      750000 non-null  float64
#  11  len_sq                       750000 non-null  float64
#  12  len_cubert                   750000 non-null  float64
#  13  host_log                     750000 non-null  float64
#  14  host_sq                      750000 non-null  float64
#  15  guest_log                    750000 non-null  float64
#  16  guest_sq                     750000 non-null  float64
#  17  pop_diff                     750000 non-null  float64
#  18  pop_sum                      750000 non-null  float64
#  19  pop_ratio                    750000 non-null  float64
#  20  ads_log                      750000 non-null  float64
#  21  ads_per_min                  750000 non-null  float64
# dtypes: float64(22)
# memory usage: 131.6 MB

# %% [markdown]
# # Model Selection

# %%
# We separate the data into training and validation sets

x_train, x_val, y_train, y_val = (
    train_test_split(
        x_end, y_listening, test_size=0.2, random_state=42
    )
)

# %%
# Create the KFold object

kfold = KFold(n_splits=10, shuffle=True, random_state=42)

# %% [markdown]
# ## XGBRegressor

# %%
# We create the model instance

xgbr = XGBRegressor()

# Train the model with the data

#xgbr.fit(x_train, y_train)

# %%
xgbr.get_params()
# Out:
# {'objective': 'reg:squarederror',
#  'base_score': None,
#  'booster': None,
#  'callbacks': None,
#  'colsample_bylevel': None,
#  'colsample_bynode': None,
#  'colsample_bytree': None,
#  'device': None,
#  'early_stopping_rounds': None,
#  'enable_categorical': False,
#  'eval_metric': None,
#  'feature_types': None,
#  'gamma': None,
#  'grow_policy': None,
#  'importance_type': None,
#  'interaction_constraints': None,
#  'learning_rate': None,
#  'max_bin': None,
#  'max_cat_threshold': None,
#  'max_cat_to_onehot': None,
#  'max_delta_step': None,
#  'max_depth': None,
#  'max_leaves': None,
#  'min_child_weight': None,
#  'missing': nan,
#  'monotone_constraints': None,
#  'multi_strategy': None,
#  'n_estimators': None,
#  'n_jobs': None,
#  'num_parallel_tree': None,
#  'random_state': None,
#  'reg_alpha': None,
#  'reg_lambda': None,
#  'sampling_method': None,
#  'scale_pos_weight': None,
#  'subsample': None,
#  'tree_method': None,
#  'validate_parameters': None,
#  'verbosity': None}

# %%
'''
# We establish the parameters to test

xgbr_param_grid = {
    "gamma" : [0.1, 0.5, 0.8, 0, 1],
    "max_depth" : [3, 4, 5, 6, 7],
    "learning_rate" : [0.2, 0.1, 0.01, 0.001],
    "subsample" : [0.5, 0.6, 0.7, 0.8, 0.9, 1],
    "n_estimators" : [50, 100, 150, 200]
}

xgbr_grid = RandomizedSearchCV(
    xgbr,
    xgbr_param_grid,
    cv=kfold,
    scoring="neg_root_mean_squared_error",
    return_train_score=True
)

xgbr_search = xgbr_grid.fit(x_train, y_train)

print(
    f'Parameters: {xgbr_search.best_params_}\nScore: {xgbr_search.best_score_}'
)
'''
# Out:
# '\n# We establish the parameters to test\n\nxgbr_param_grid = {\n    "gamma" : [0.1, 0.5, 0.8, 0, 1],\n    "max_depth" : [3, 4, 5, 6, 7],\n    "learning_rate" : [0.2, 0.1, 0.01, 0.001],\n    "subsample" : [0.5, 0.6, 0.7, 0.8, 0.9, 1],\n    "n_estimators" : [50, 100, 150, 200]\n}\n\nxgbr_grid = RandomizedSearchCV(\n    xgbr,\n    xgbr_param_grid,\n    cv=kfold,\n    scoring="neg_root_mean_squared_error",\n    return_train_score=True\n)\n\nxgbr_search = xgbr_grid.fit(x_train, y_train)\n\nprint(\n    f\'Parameters: {xgbr_search.best_params_}\nScore: {xgbr_search.best_score_}\'\n)\n'

# %%
# We evaluate the performance after an initial optimization

#y_pred_xgbr = xgbr_search.best_estimator_.predict(x_val)

#r2_xgbr = r2_score(y_val, y_pred_xgbr)

#rmse_xgbr = np.sqrt(mean_squared_error(y_val, y_pred_xgbr))

#print(f"XGBRegressor optimization\n\nR-squared score: {r2_xgbr}\nRMSE: {rmse_xgbr}")

# %% [markdown]
# - With data dropped in variable management
#
#       RandomizedSearchCV:
#
#       Parameters: {'subsample':0.9, 'n_estimators':150, 'max_depth':6, 'learning_rate':0.2, 'gamma':0.1}
#
#       Score: -10.385593205700733
#
#       R-squared score: 0.8548779072393202
#
#       RMSE: 10.359859724404574

# %%
'''
# XGBR different approaches

#xgbr_final = xgbr_search.best_estimator_
xgbr_final = XGBRegressor(
    subsample = 0.9, n_estimators = 150, max_depth = 6, learning_rate = 0.2, gamma = 0.1
)
xgbr_final.fit(x_train, y_train)
'''
# Out:
# '\n# XGBR different approaches\n\n#xgbr_final = xgbr_search.best_estimator_\nxgbr_final = XGBRegressor(\n    subsample = 0.9, n_estimators = 150, max_depth = 6, learning_rate = 0.2, gamma = 0.1\n)\nxgbr_final.fit(x_train, y_train)\n'

# %% [markdown]
# ## BaggingRegressor

# %%
# We create the model instance

bagr = BaggingRegressor()

# Train the model with the data

#bagr.fit(x_train, y_train)

# %%
'''
y_pred_bagr = bagr.predict(x_val)

r2_bagr = r2_score(y_val, y_pred_bagr)

rmse_bagr = np.sqrt(mean_squared_error(y_val, y_pred_bagr))

print(f"BaggingRegressor\n\nR-squared score: {r2_bagr}\nRMSE: {rmse_bagr}")
'''
# Out:
# '\ny_pred_bagr = bagr.predict(x_val)\n\nr2_bagr = r2_score(y_val, y_pred_bagr)\n\nrmse_bagr = np.sqrt(mean_squared_error(y_val, y_pred_bagr))\n\nprint(f"BaggingRegressor\n\nR-squared score: {r2_bagr}\nRMSE: {rmse_bagr}")\n'

# %% [markdown]
# BaggingRegressor (Default)
#
# R-squared score: 0.7586370826352582
#
# RMSE: 13.326718743148652

# %%
bagr.get_params()
# Out:
# {'base_estimator': 'deprecated',
#  'bootstrap': True,
#  'bootstrap_features': False,
#  'estimator': None,
#  'max_features': 1.0,
#  'max_samples': 1.0,
#  'n_estimators': 10,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
'''
# We establish the parameters to test

bagr_param_grid = {
    "estimator" : [None, xgbr, xgbr_final],
    "max_features" : [0.2, 0.5, 1.0],
    "max_samples" : [0.2, 0.5, 1.0],
    "n_estimators" : [10, 20, 30]
}

bagr_grid = RandomizedSearchCV(
    bagr,
    bagr_param_grid,
    cv=kfold,
    scoring="neg_root_mean_squared_error",
    return_train_score=True
)

bagr_search = bagr_grid.fit(x_train, y_train)

print(
    f'Parameters: {bagr_search.best_params_}\nScore: {bagr_search.best_score_}'
)
'''
# Out:
# '\n# We establish the parameters to test\n\nbagr_param_grid = {\n    "estimator" : [None, xgbr, xgbr_final],\n    "max_features" : [0.2, 0.5, 1.0],\n    "max_samples" : [0.2, 0.5, 1.0],\n    "n_estimators" : [10, 20, 30]\n}\n\nbagr_grid = RandomizedSearchCV(\n    bagr,\n    bagr_param_grid,\n    cv=kfold,\n    scoring="neg_root_mean_squared_error",\n    return_train_score=True\n)\n\nbagr_search = bagr_grid.fit(x_train, y_train)\n\nprint(\n    f\'Parameters: {bagr_search.best_params_}\nScore: {bagr_search.best_score_}\'\n)\n'

# %% [markdown]
# Parameters: {'n_estimators': 20, 'max_samples': 1.0, 'max_features': 1.0, 'estimator': XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0.1, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.2, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=6, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=150, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)}
#
# Score: -13.031101049045333

# %%
'''
# We evaluate the performance after an initial optimization

y_pred_bagr = bagr_search.best_estimator_.predict(x_val)

r2_bagr = r2_score(y_val, y_pred_bagr)

rmse_bagr = np.sqrt(mean_squared_error(y_val, y_pred_bagr))

print(f"BaggingRegressor optimization\n\nR-squared score: {r2_bagr}\nRMSE: {rmse_bagr}")
'''
# Out:
# '\n# We evaluate the performance after an initial optimization\n\ny_pred_bagr = bagr_search.best_estimator_.predict(x_val)\n\nr2_bagr = r2_score(y_val, y_pred_bagr)\n\nrmse_bagr = np.sqrt(mean_squared_error(y_val, y_pred_bagr))\n\nprint(f"BaggingRegressor optimization\n\nR-squared score: {r2_bagr}\nRMSE: {rmse_bagr}")\n'

# %% [markdown]
# BaggingRegressor optimization
#
# R-squared score: 0.7705749925584561
#
# RMSE: 12.992967020835195

# %%
# BAGR different approaches

#bagr_final = bagr_search.best_estimator_

#bagr_final = BaggingRegressor(n_estimators=20, max_samples=1.0, max_features=1.0, estimator=xgbr_final)

#bagr_final.fit(x_train, y_train)

# %% [markdown]
# ## CatBoostRegressor

# %%
# Initialize the CatBoostRegressor with RMSE as the loss function 
cbr = CatBoostRegressor(loss_function="RMSE", silent=True) 
  
# Fit the model
#cbr.fit(x_train, y_train)

# %%
'''
y_pred_cbr = cbr.predict(x_val)

r2_cbr = r2_score(y_val, y_pred_cbr)

rmse_cbr = np.sqrt(mean_squared_error(y_val, y_pred_cbr))

print(f"CatBoostRegressor\n\nR-squared score: {r2_cbr}\nRMSE: {rmse_cbr}")
'''
# Out:
# '\ny_pred_cbr = cbr.predict(x_val)\n\nr2_cbr = r2_score(y_val, y_pred_cbr)\n\nrmse_cbr = np.sqrt(mean_squared_error(y_val, y_pred_cbr))\n\nprint(f"CatBoostRegressor\n\nR-squared score: {r2_cbr}\nRMSE: {rmse_cbr}")\n'

# %% [markdown]
# CatBoostRegressor
#
# R-squared score: 0.7695329849820068
#
# RMSE: 13.022439466683332

# %%
'''
# We establish the parameters to test

cbr_param_grid = {
    "learning_rate" : [0.001, 0.01, 0.004],
    "max_depth" : [3,4,5],
    "l2_leaf_reg" : [1.0, 5.0, 0.5],
    "min_child_samples" : [1,3,6]
}

cbr_grid = RandomizedSearchCV(
    cbr,
    cbr_param_grid,
    cv=kfold,
    scoring="neg_root_mean_squared_error",
    return_train_score=True
)

cbr_search = cbr_grid.fit(x_train, y_train)

print(
    f'Parameters: {cbr_search.best_params_}\nScore: {cbr_search.best_score_}'
)
'''
# Out:
# '\n# We establish the parameters to test\n\ncbr_param_grid = {\n    "learning_rate" : [0.001, 0.01, 0.004],\n    "max_depth" : [3,4,5],\n    "l2_leaf_reg" : [1.0, 5.0, 0.5],\n    "min_child_samples" : [1,3,6]\n}\n\ncbr_grid = RandomizedSearchCV(\n    cbr,\n    cbr_param_grid,\n    cv=kfold,\n    scoring="neg_root_mean_squared_error",\n    return_train_score=True\n)\n\ncbr_search = cbr_grid.fit(x_train, y_train)\n\nprint(\n    f\'Parameters: {cbr_search.best_params_}\nScore: {cbr_search.best_score_}\'\n)\n'

# %% [markdown]
# CatBoostRegressor optimization
#
# Parameters: {'min_child_samples': 3, 'max_depth': 5, 'learning_rate': 0.01, 'l2_leaf_reg': 0.5}
#
# Score: -13.197115784814908

# %%
'''
# We evaluate the performance after an initial optimization

y_pred_cbr_s = cbr_search.best_estimator_.predict(x_val)

r2_cbr_s = r2_score(y_val, y_pred_cbr_s)

rmse_cbr_s = np.sqrt(mean_squared_error(y_val, y_pred_cbr_s))

print(f"CatBoostRegressor\n\nR-squared score: {r2_cbr_s}\nRMSE: {rmse_cbr_s}")
'''
# Out:
# '\n# We evaluate the performance after an initial optimization\n\ny_pred_cbr_s = cbr_search.best_estimator_.predict(x_val)\n\nr2_cbr_s = r2_score(y_val, y_pred_cbr_s)\n\nrmse_cbr_s = np.sqrt(mean_squared_error(y_val, y_pred_cbr_s))\n\nprint(f"CatBoostRegressor\n\nR-squared score: {r2_cbr_s}\nRMSE: {rmse_cbr_s}")\n'

# %% [markdown]
# CatBoostRegressor First approach
#
# R-squared score: 0.7651383208535669
# RMSE: 13.146012462379785

# %% [markdown]
# # Final Model

# %%
# We define the final model

final_model = cbr

# We fit the best model

final_model.fit(x_train, y_train)

# %%
# We evaluate the performance of the final model

final_model_ypred = final_model.predict(x_val)

final_model_rmse = np.sqrt(mean_squared_error(y_val, final_model_ypred))

print("Final Model RMSE Score: %.3f" % final_model_rmse)
# Out:
# Final Model RMSE Score: 13.029

# %% [markdown]
# bagr Model RMSE Score: 13.337
#
# bagr, estimator=xgbr_final Model RMSE Score: 12.992

# %%
'''
# We create an explainer for the best estimator

explainer = shap.Explainer(final_model)
shap_values = explainer.shap_values(x_val)

# we visualize the importance

fig = shap.summary_plot(
    shap_values,
    x_val,
    show=False
)
plt.title("Feature Importance", fontsize=20, color='g', loc='left')
plt.xlabel("Mean SHAP Values", fontsize=20)
plt.ylabel("Features", fontsize=20)
plt.show()
'''
# Out:
# '\n# We create an explainer for the best estimator\n\nexplainer = shap.Explainer(final_model)\nshap_values = explainer.shap_values(x_val)\n\n# we visualize the importance\n\nfig = shap.summary_plot(\n    shap_values,\n    x_val,\n    show=False\n)\nplt.title("Feature Importance", fontsize=20, color=\'g\', loc=\'left\')\nplt.xlabel("Mean SHAP Values", fontsize=20)\nplt.ylabel("Features", fontsize=20)\nplt.show()\n'

# %% [markdown]
# # Test data

# %%
# We load the test data

df_test = pd.read_csv("/kaggle/input/playground-series-s5e4/test.csv")

# %%
df_test_new = df_test.copy()

# %%
# We check the null values

null_values_test = (
    pd.DataFrame(
        {f"Amount of Null Data" : df_test_new.isnull().sum(), 
         "Percentage of Null Data" : (
             df_test_new.isnull().sum()) / (len(df_test_new)) * (100)
        }
    ))

null_values_test.style.background_gradient(cmap="Greens")
# Out:
# <style type="text/css">
# #T_7ef66_row0_col0, #T_7ef66_row0_col1, #T_7ef66_row1_col0, #T_7ef66_row1_col1, #T_7ef66_row2_col0, #T_7ef66_row2_col1, #T_7ef66_row4_col0, #T_7ef66_row4_col1, #T_7ef66_row5_col0, #T_7ef66_row5_col1, #T_7ef66_row6_col0, #T_7ef66_row6_col1, #T_7ef66_row7_col0, #T_7ef66_row7_col1, #T_7ef66_row9_col0, #T_7ef66_row9_col1, #T_7ef66_row10_col0, #T_7ef66_row10_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_7ef66_row3_col0, #T_7ef66_row3_col1 {
#   background-color: #50b264;
#   color: #f1f1f1;
# }
# #T_7ef66_row8_col0, #T_7ef66_row8_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7ef66">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7ef66_level0_col0" class="col_heading level0 col0" >Amount of Null Data</th>
#       <th id="T_7ef66_level0_col1" class="col_heading level0 col1" >Percentage of Null Data</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ef66_level0_row0" class="row_heading level0 row0" >id</th>
#       <td id="T_7ef66_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_7ef66_row0_col1" class="data row0 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7ef66_level0_row1" class="row_heading level0 row1" >Podcast_Name</th>
#       <td id="T_7ef66_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_7ef66_row1_col1" class="data row1 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7ef66_level0_row2" class="row_heading level0 row2" >Episode_Title</th>
#       <td id="T_7ef66_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_7ef66_row2_col1" class="data row2 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7ef66_level0_row3" class="row_heading level0 row3" >Episode_Length_minutes</th>
#       <td id="T_7ef66_row3_col0" class="data row3 col0" >28736</td>
#       <td id="T_7ef66_row3_col1" class="data row3 col1" >11.494400</td>
#     </tr>
#     <tr>
#       <th id="T_7ef66_level0_row4" class="row_heading level0 row4" >Genre</th>
#       <td id="T_7ef66_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_7ef66_row4_col1" class="data row4 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7ef66_level0_row5" class="row_heading level0 row5" >Host_Popularity_percentage</th>
#       <td id="T_7ef66_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_7ef66_row5_col1" class="data row5 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7ef66_level0_row6" class="row_heading level0 row6" >Publication_Day</th>
#       <td id="T_7ef66_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_7ef66_row6_col1" class="data row6 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7ef66_level0_row7" class="row_heading level0 row7" >Publication_Time</th>
#       <td id="T_7ef66_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_7ef66_row7_col1" class="data row7 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7ef66_level0_row8" class="row_heading level0 row8" >Guest_Popularity_percentage</th>
#       <td id="T_7ef66_row8_col0" class="data row8 col0" >48832</td>
#       <td id="T_7ef66_row8_col1" class="data row8 col1" >19.532800</td>
#     </tr>
#     <tr>
#       <th id="T_7ef66_level0_row9" class="row_heading level0 row9" >Number_of_Ads</th>
#       <td id="T_7ef66_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_7ef66_row9_col1" class="data row9 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7ef66_level0_row10" class="row_heading level0 row10" >Episode_Sentiment</th>
#       <td id="T_7ef66_row10_col0" class="data row10 col0" >0</td>
#       <td id="T_7ef66_row10_col1" class="data row10 col1" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# We start by removing the variables that we will not use

df_test_new = df_test_new.drop(columns="id")

# %%
# We replace the erroneous values

df_test_new["Number_of_Ads"] = (df_test_new["Number_of_Ads"].apply(lambda x: np.NaN if x>3 else x))
df_test_new["Episode_Length_minutes"] = (
    df_test_new["Episode_Length_minutes"].apply(lambda x: np.NaN if x>125.0 else x)
)
df_test_new["Host_Popularity_percentage"] = np.where(
    df_test_new["Host_Popularity_percentage"] > 100, 100, df_test_new["Host_Popularity_percentage"]
).round(decimals=2)
df_test_new["Guest_Popularity_percentage"] = np.where(
    df_test_new["Guest_Popularity_percentage"] > 100, 100, df_test_new["Guest_Popularity_percentage"]
).round(decimals=2)

# %%
'''
# We filled in null values with KNNImputer

test_object = df_test_new.select_dtypes(include="object")
test_impute = df_test_new.select_dtypes(include="number")

imputer = KNNImputer().set_output(transform="pandas")
after_imputation = imputer.fit_transform(test_impute)

df_test_new = pd.concat([test_object, after_imputation], axis=1)
'''
# Out:
# '\n# We filled in null values with KNNImputer\n\ntest_object = df_test_new.select_dtypes(include="object")\ntest_impute = df_test_new.select_dtypes(include="number")\n\nimputer = KNNImputer().set_output(transform="pandas")\nafter_imputation = imputer.fit_transform(test_impute)\n\ndf_test_new = pd.concat([test_object, after_imputation], axis=1)\n'

# %%
# We filled in null values

df_test_new["Number_of_Ads"] = (df_test_new["Number_of_Ads"].fillna(
    df_test_new.groupby("Podcast_Name")["Number_of_Ads"].transform(lambda v: v.mode()[0])
))
df_test_new["Episode_Length_minutes"] = (df_test_new["Episode_Length_minutes"].fillna(
    df_test_new.groupby("Podcast_Name")["Episode_Length_minutes"].transform("median")
))
df_test_new["Guest_Popularity_percentage"] = (df_test_new["Guest_Popularity_percentage"].fillna(
    df_test_new.groupby("Podcast_Name")["Guest_Popularity_percentage"].transform("median")
))

# %%
# Feature engineering on test data

df_test_new["len_log"] = np.log1p(df_test_new["Episode_Length_minutes"])
df_test_new["len_sq"]  = df_test_new["Episode_Length_minutes"] ** 2
df_test_new["len_cubert"] = np.cbrt(df_test_new["Episode_Length_minutes"])

df_test_new["host_log"] = np.log1p(df_test_new["Host_Popularity_percentage"])
df_test_new["host_sq"] = df_test_new["Host_Popularity_percentage"] ** 2
df_test_new["guest_log"] = np.log1p(df_test_new["Guest_Popularity_percentage"])
df_test_new["guest_sq"] = df_test_new["Guest_Popularity_percentage"] ** 2
df_test_new["pop_diff"] = df_test_new["Host_Popularity_percentage"] - df_test_new["Guest_Popularity_percentage"]
df_test_new["pop_sum"] = df_test_new["Host_Popularity_percentage"] + df_test_new["Guest_Popularity_percentage"]
df_test_new["pop_ratio"] = df_test_new["Host_Popularity_percentage"] / (df_test_new["Guest_Popularity_percentage"] + 1)

df_test_new["ads_log"] = np.log1p(df_test_new["Number_of_Ads"])
df_test_new["ads_per_min"] = df_test_new["Number_of_Ads"] / (df_test_new["Episode_Length_minutes"] + 1)

# %%
# We encode the categorical variables

df_test_new["Episode_Sentiment"] = df_test_new["Episode_Sentiment"].map(eps_order)
df_test_new["Episode_Sentiment"] = df_test_new["Episode_Sentiment"].astype("float64")

df_test_new["Episode_Title"] = df_test_new["Episode_Title"].str.strip("Episode ").astype("float64")

test_num = df_test_new.select_dtypes(include="number")
test_cat = df_test_new.select_dtypes(include="object")
test_enc = enc.fit_transform(test_cat)
test_encoded = pd.concat([test_enc, test_num], axis=1)

# %%
# We scale the test variables

test_numeric = test_encoded[[
    "Podcast_Name",
    "Episode_Title",
    "Episode_Length_minutes",
    "Host_Popularity_percentage",
    "Guest_Popularity_percentage"
]]

test_scale_num = scaler.transform(test_numeric)

test_rest = test_encoded[[
    "Genre",
    "Publication_Day",
    "Publication_Time",
    "Number_of_Ads",
    "Episode_Sentiment"
]]

test_fe = test_encoded.drop(columns=
                             ["Podcast_Name",
                             "Episode_Title",
                             "Episode_Length_minutes",
                             "Host_Popularity_percentage",
                             "Guest_Popularity_percentage",
                             "Genre",
                             "Publication_Day",
                             "Publication_Time",
                             "Number_of_Ads",
                             "Episode_Sentiment"]
                            )

test_scale_mm = mm_scaler.transform(test_fe)

# We concatenate the dataframes

test_end = pd.concat([test_rest, test_scale_num, test_scale_mm], axis=1)

# %%
test_end.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Genre                        250000 non-null  float64
#  1   Publication_Day              250000 non-null  float64
#  2   Publication_Time             250000 non-null  float64
#  3   Number_of_Ads                250000 non-null  float64
#  4   Episode_Sentiment            250000 non-null  float64
#  5   Podcast_Name                 250000 non-null  float64
#  6   Episode_Title                250000 non-null  float64
#  7   Episode_Length_minutes       250000 non-null  float64
#  8   Host_Popularity_percentage   250000 non-null  float64
#  9   Guest_Popularity_percentage  250000 non-null  float64
#  10  len_log                      250000 non-null  float64
#  11  len_sq                       250000 non-null  float64
#  12  len_cubert                   250000 non-null  float64
#  13  host_log                     250000 non-null  float64
#  14  host_sq                      250000 non-null  float64
#  15  guest_log                    250000 non-null  float64
#  16  guest_sq                     250000 non-null  float64
#  17  pop_diff                     250000 non-null  float64
#  18  pop_sum                      250000 non-null  float64
#  19  pop_ratio                    250000 non-null  float64
#  20  ads_log                      250000 non-null  float64
#  21  ads_per_min                  250000 non-null  float64
# dtypes: float64(22)
# memory usage: 42.0 MB

# %%
test_end.describe().T
# Out:
#                                 count      mean       std       min       25%  \
# Genre                        250000.0  4.641336  2.959436  0.000000  2.000000
# Publication_Day              250000.0  2.962788  1.993649  0.000000  1.000000
# Publication_Time             250000.0  1.522652  1.118540  0.000000  1.000000
# Number_of_Ads                250000.0  1.347248  1.112669  0.000000  0.000000
# Episode_Sentiment            250000.0  0.997236  0.815666  0.000000  0.000000
# Podcast_Name                 250000.0 -0.001865  0.998106 -1.663351 -0.885282
# Episode_Title                250000.0 -0.000884  0.998834 -1.796145 -0.834798
# Episode_Length_minutes       250000.0  0.001821  1.000222 -1.998496 -0.808364
# Host_Popularity_percentage   250000.0 -0.006268  1.000309 -2.508262 -0.901071
# Guest_Popularity_percentage  250000.0 -0.002686  0.999432 -2.055025 -0.702267
# len_log                      250000.0  0.837698  0.131541  0.259013  0.769882
# len_sq                       250000.0  0.350153  0.281500  0.000417  0.105989
# len_cubert                   250000.0  0.784076  0.151139  0.273351  0.687929
# host_log                     250000.0  0.843742  0.111742  0.110251  0.756753
# host_sq                      250000.0  0.408847  0.277846  0.000451  0.153913
# guest_log                    250000.0  0.819108  0.166234  0.000000  0.773748
# guest_sq                     250000.0  0.339917  0.268589  0.000000  0.119370
# pop_diff                     250000.0  0.483721  0.189112 -0.000167  0.347375
# pop_sum                      250000.0  0.543754  0.179908  0.000728  0.414324
# pop_ratio                    250000.0  0.022067  0.047239  0.000247  0.007005
# ads_log                      250000.0  0.522880  0.379320  0.000000  0.000000
# ads_per_min                  250000.0  0.062666  0.092021  0.000000  0.000000
#
#                                   50%       75%       max
# Genre                        5.000000  7.000000  9.000000
# Publication_Day              3.000000  5.000000  6.000000
# Publication_Time             1.000000  3.000000  3.000000
# Number_of_Ads                1.000000  2.000000  3.000000
# Episode_Sentiment            1.000000  2.000000  2.000000
# Podcast_Name                -0.036479  0.883056  1.661125
# Episode_Title                0.019732  0.838657  1.728793
# Episode_Length_minutes      -0.014297  0.841050  1.815733
# Host_Popularity_percentage   0.001771  0.853897  1.754991
# Guest_Popularity_percentage  0.032647  0.724491  1.860338
# len_log                      0.869008  0.940251  0.999658
# len_sq                       0.279999  0.560177  0.996695
# len_cubert                   0.808834  0.907934  0.999448
# host_log                     0.866246  0.939657  1.000000
# host_sq                      0.358693  0.630215  1.000000
# guest_log                    0.865610  0.926634  1.000000
# guest_sq                     0.284302  0.503958  1.000000
# pop_diff                     0.480441  0.615179  0.998774
# pop_sum                      0.546541  0.673198  1.000000
# pop_ratio                    0.010909  0.017403  0.970616
# ads_log                      0.500000  0.792481  1.000000
# ads_per_min                  0.037115  0.078536  1.311674

# %%
# We apply the trained model

listening_predictions = final_model.predict(test_end)

# %%
# We review the result

print("Total predictions: ", len(listening_predictions), "\n")
# Out:
# Total predictions:  250000

# %%
# We create the dataframe

listening_submission = pd.DataFrame({
    "id" : df_test["id"], 
    "Listening_Time_minutes" : listening_predictions
})

listening_submission.head()
# Out:
#        id  Listening_Time_minutes
# 0  750000               55.391280
# 1  750001               18.069467
# 2  750002               48.422379
# 3  750003               76.647511
# 4  750004               49.052827

# %%
# We convert the dataframe to a csv file

listening_submission.to_csv("submission.csv", index=False)
